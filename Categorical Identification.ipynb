# %%
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 9s 0us/step

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

# %%
model = Sequential()


model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), activation='relu'))
model.add(Conv2D(32, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(units=512, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(units=100, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100,batch_size = 32)

loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 48s 30ms/step - loss: 4.0252 - accuracy: 0.0829
# Epoch 2/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 3.4624 - accuracy: 0.1741
# Epoch 3/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 3.1768 - accuracy: 0.2241
# Epoch 4/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 3.0011 - accuracy: 0.2606
# Epoch 5/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.8688 - accuracy: 0.2852
# Epoch 6/100
# 1563/1563 [==============================] - 49s 32ms/step - loss: 2.7732 - accuracy: 0.3026
# Epoch 7/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.6824 - accuracy: 0.3209
# Epoch 8/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.6057 - accuracy: 0.3361
# Epoch 9/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.5520 - accuracy: 0.3473
# Epoch 10/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.4962 - accuracy: 0.3558
# Epoch 11/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.4575 - accuracy: 0.3620
# Epoch 12/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.4154 - accuracy: 0.3730
# Epoch 13/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.3749 - accuracy: 0.3791
# Epoch 14/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.3414 - accuracy: 0.3873
# Epoch 15/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.3092 - accuracy: 0.3929
# Epoch 16/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 2.2757 - accuracy: 0.4008
# Epoch 17/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 2.2488 - accuracy: 0.4079
# Epoch 18/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.2252 - accuracy: 0.4117
# Epoch 19/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.1992 - accuracy: 0.4176
# Epoch 20/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.1821 - accuracy: 0.4220
# Epoch 21/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.1502 - accuracy: 0.4257
# Epoch 22/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.1362 - accuracy: 0.4293
# Epoch 23/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.1249 - accuracy: 0.4318
# Epoch 24/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0959 - accuracy: 0.4380
# Epoch 25/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0853 - accuracy: 0.4396
# Epoch 26/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0645 - accuracy: 0.4431
# Epoch 27/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0514 - accuracy: 0.4489
# Epoch 28/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0473 - accuracy: 0.4465
# Epoch 29/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0252 - accuracy: 0.4541
# Epoch 30/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0082 - accuracy: 0.4562
# Epoch 31/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 2.0076 - accuracy: 0.4578
# Epoch 32/100
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.9950 - accuracy: 0.4574
# Epoch 33/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.9777 - accuracy: 0.4636
# Epoch 34/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.9757 - accuracy: 0.4632
# Epoch 35/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.9731 - accuracy: 0.4640
# Epoch 36/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.9557 - accuracy: 0.4662
# Epoch 37/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.9467 - accuracy: 0.4700
# Epoch 38/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.9389 - accuracy: 0.4699
# Epoch 39/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.9307 - accuracy: 0.4732
# Epoch 40/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.9255 - accuracy: 0.4730
# Epoch 41/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.9133 - accuracy: 0.4793
# Epoch 42/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.9085 - accuracy: 0.4782
# Epoch 43/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8838 - accuracy: 0.4833
# Epoch 44/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8920 - accuracy: 0.4833
# Epoch 45/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8783 - accuracy: 0.4850
# Epoch 46/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8803 - accuracy: 0.4846
# Epoch 47/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8725 - accuracy: 0.4854
# Epoch 48/100
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.8790 - accuracy: 0.4839
# Epoch 49/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8592 - accuracy: 0.4881
# Epoch 50/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8557 - accuracy: 0.4914
# Epoch 51/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8506 - accuracy: 0.4920
# Epoch 52/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8545 - accuracy: 0.4907
# Epoch 53/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8451 - accuracy: 0.4953
# Epoch 54/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8458 - accuracy: 0.4918
# Epoch 55/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8385 - accuracy: 0.4940
# Epoch 56/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8327 - accuracy: 0.4932
# Epoch 57/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8256 - accuracy: 0.4947
# Epoch 58/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8201 - accuracy: 0.4988
# Epoch 59/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8112 - accuracy: 0.5028
# Epoch 60/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8122 - accuracy: 0.4994
# Epoch 61/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8080 - accuracy: 0.5010
# Epoch 62/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8171 - accuracy: 0.5002
# Epoch 63/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.8046 - accuracy: 0.5012
# Epoch 64/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.8035 - accuracy: 0.5001
# Epoch 65/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7995 - accuracy: 0.5034
# Epoch 66/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7924 - accuracy: 0.5058
# Epoch 67/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7885 - accuracy: 0.5065
# Epoch 68/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7806 - accuracy: 0.5043
# Epoch 69/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7906 - accuracy: 0.5047
# Epoch 70/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7613 - accuracy: 0.5096
# Epoch 71/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7766 - accuracy: 0.5086
# Epoch 72/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7792 - accuracy: 0.5047
# Epoch 73/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7701 - accuracy: 0.5084
# Epoch 74/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7717 - accuracy: 0.5090
# Epoch 75/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7687 - accuracy: 0.5111
# Epoch 76/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7703 - accuracy: 0.5078
# Epoch 77/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7577 - accuracy: 0.5119
# Epoch 78/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7609 - accuracy: 0.5100
# Epoch 79/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7578 - accuracy: 0.5121
# Epoch 80/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7647 - accuracy: 0.5114
# Epoch 81/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7501 - accuracy: 0.5138
# Epoch 82/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7562 - accuracy: 0.5111
# Epoch 83/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7553 - accuracy: 0.5129
# Epoch 84/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7528 - accuracy: 0.5132
# Epoch 85/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7384 - accuracy: 0.5183
# Epoch 86/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7533 - accuracy: 0.5129
# Epoch 87/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7554 - accuracy: 0.5132
# Epoch 88/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7421 - accuracy: 0.5166
# Epoch 89/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7280 - accuracy: 0.5204
# Epoch 90/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7486 - accuracy: 0.5175
# Epoch 91/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7366 - accuracy: 0.5175
# Epoch 92/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7404 - accuracy: 0.5170
# Epoch 93/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7346 - accuracy: 0.5171
# Epoch 94/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7489 - accuracy: 0.5160
# Epoch 95/100
# 1563/1563 [==============================] - 50s 32ms/step - loss: 1.7268 - accuracy: 0.5201
# Epoch 96/100
# 1563/1563 [==============================] - 49s 32ms/step - loss: 1.7263 - accuracy: 0.5202
# Epoch 97/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7281 - accuracy: 0.5175
# Epoch 98/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7374 - accuracy: 0.5164
# Epoch 99/100
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.7265 - accuracy: 0.5208
# Epoch 100/100
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.7240 - accuracy: 0.5194
# 313/313 [==============================] - 2s 6ms/step - loss: 2.2916 - accuracy: 0.4281

# %%
print(loss,accuracy)
# Out:
# 2.2915725708007812 0.42809998989105225
